# %%
from IPython.display import Image, YouTubeVideo

# %%
Image("fromSToML.png")

# %% [markdown]
# # Introduction to Probability ans Statistics

# %%
YouTubeVideo(id="XOBoVl-iPpw", width=900, height=400)

# %% [markdown]
# # Population and Sample

# %%
YouTubeVideo(id="pcJwjBeAzzs", width=900, height=400)

# %% [markdown]
# # Gaussian/Normal Distribution and its PDF(Probability Density Function)

# %%
YouTubeVideo(id="s0AvHLICl5g", width=900, height=400)

# %% [markdown]
# # CDF(Cumulative Distribution function) of Gaussian/Normal distribution

# %%
YouTubeVideo(id="GVXH10_Dkms", width=900, height=400)

# %% [markdown]
# # Statistical distribution

# %%
YouTubeVideo(id="oI3hZJqXJuc", width=900, height=400)

# %% [markdown]
# # Skewness and Kurtosis

# %%
YouTubeVideo(id="WjdpbO3s-sQ", width=900, height=400)

# %% [markdown]
# # The Normal Distribution

# %%
YouTubeVideo(id="rzFX5NWojp0", width=900, height=400)

# %% [markdown]
# # Z-Scores, Standardization, and the Standard Normal Distribution

# %%
YouTubeVideo(id="2tuBREK_mgE", width=900, height=400)

# %% [markdown]
#  # Kernel Density Estimation(KDE)

# %%
YouTubeVideo(id="DCgPRaIDYXA", width=900, height=400)
