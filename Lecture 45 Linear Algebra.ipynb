# %% [markdown]
# # Why learn it ?

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

from mpl_toolkits.mplot3d import Axes3D
from IPython.display import Image, YouTubeVideo

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
YouTubeVideo(id="Y25M0NhTO4U", width=900, height=400)

# %% [markdown]
# ## Algebraic and geometric interpretations

# %%
# 2-dimensional vector
v2 = [ 3, -2 ]

# 3-dimensional vector
v3 = [ 4, -3, 2 ]

# row to column (or vice-versa):
v3t = np.transpose(v3)


# plot them
plt.plot([0,v2[0]],[0,v2[1]])
plt.axis('auto')
plt.plot([-4, 4],[0, 0],'k--')
plt.plot([0, 0],[-4, 4],'k--')
plt.grid()
plt.axis((-4, 4, -4, 4))
plt.show()


# plot the 3D vector
fig = plt.figure()
ax = fig.gca(projection='3d')
ax.plot([0, v3[0]],[0, v3[1]],[0, v3[2]])

# make the plot look nicer
plt.axis('auto')
ax.plot([0, 0],[0, 0],[-4, 4],'k--')
ax.plot([0, 0],[-4, 4],[0, 0],'k--')
ax.plot([-4, 4],[0, 0],[0, 0],'k--')
plt.show()

# %% [markdown]
# # Introduction to Vectors(2-D, 3-D, n-D) , Row Vector and Column Vector

# %%
YouTubeVideo(id="Eqi20D-b2sU", width=900, height=400)
