# %% [markdown]
# # How to measure the effectiveness of k-NN?

# %%
import numpy as np
import pandas as pd 

from IPython.display import YouTubeVideo, Image

# %%
YouTubeVideo(id="NL_oV9O4k2s", width=900, height=450)

# %% [markdown]
# # Test Evaluation Time and Space complexity

# %%
YouTubeVideo(id="MjQUULGTq14", width=900, height=450)

# %% [markdown]
# # KNN Limitations

# %%
YouTubeVideo(id="bXj0vWxHB5U", width=900, height=450)

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
