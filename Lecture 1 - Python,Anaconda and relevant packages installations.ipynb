# %%
from IPython.display import YouTubeVideo, HTML, Image

# %%
# %%HTML
# <div>
# <span style="font-size:18px" align="right">Abdeljebbar BOUBEKRI (Dajebbar)</span>
# <br>
#
# <span tyle="font-size:16px">AI Programming with Python</span>
# <br>
# <span><b>Licence CC BY-NC-ND</b></span>
# </div>
# Out:
# <div>
# <span style="font-size:18px" align="right">Abdeljebbar BOUBEKRI (Dajebbar)</span>
# <br>
#
# <span tyle="font-size:16px">AI Programming with Python</span>
# <br>
# <span><b>Licence CC BY-NC-ND</b></span>
# </div>

# %%
Image('Img/neural-python.jpg', width=150, height=150)

# %% [markdown]
# # Instructions of installation:
#
# #### Notes:
#     - TensorFlow 1.x doesn’t work with python (3.7, 3.8 and 3.9), please install python version 3.6 only.
#     - Compatibility with Python 3.8 requires TensorFlow 2.2 or later
#
# Check the previous Archives of Anaconda: https://repo.continuum.io/archive/

# %% [markdown]
# ## Install Anaconda on Windows :

# %%
YouTubeVideo(id='uOwCiZKj2rg',width=900, height=400)

# %% [markdown]
# ## Install Anaconda on linux :

# %%
YouTubeVideo(id='eVMvbtdUnlg',width=900, height=400)

# %% [markdown]
# ## Install Anaconda on MacOS :

# %%
YouTubeVideo(id='2JeoNlCcLOM',width=900, height=400)

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
