# %% [markdown]
# # What is Dimensionality reduction?

# %%
from IPython.display import Image, YouTubeVideo
YouTubeVideo(id="Kc-D455GVoQ", width=900, height=400)

# %% [markdown]
# # Row Vector and Column Vector

# %%
YouTubeVideo(id="jXU3DNg5Ppg", width=900, height=400)

# %% [markdown]
# # How to represent a data set?

# %%
YouTubeVideo(id="kgmep5VSTus", width=900, height=400)

# %% [markdown]
# # How to represent a dataset as a Matrix

# %%
YouTubeVideo(id="xN_8gDdgaoE", width=900, height=400)

# %% [markdown]
# # Data Preprocessing: Feature Normalisation

# %%
YouTubeVideo(id="-ejA7qpvO0w", width=900, height=400)

# %% [markdown]
# # Mean of a data matrix

# %%
YouTubeVideo(id="6khXPEMT798", width=900, height=400)

# %% [markdown]
# # Data Preprocessing: Column Standardization

# %%
YouTubeVideo(id="Mg5ixxRmnA0", width=900, height=400)

# %% [markdown]
# # Co-variance of a Data Matrix

# %% [markdown]
# ##  Correction
# # $$S = \frac{1}{(n-1)}(X^T \times X)$$

# %%
YouTubeVideo(id="1HLLmFmy3Uw", width=900, height=400)
