# %% [markdown]
# # Pair plots

# %%
from IPython.display import YouTubeVideo
YouTubeVideo(id='b7JuBsswDlo', width=900, height=400)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('fivethirtyeight')

# %matplotlib inline

# %%
iris = pd.read_csv('iris.csv')

# %%
# pairwise scatter plot: Pair-Plot
# Dis-advantages: 
##Can't be used when number of features are high.
##Cannot visualize higher dimensional patterns in 3-D and 4-D. 
#Only possible to view 2D patterns.

plt.close();
sns.pairplot(iris, hue='species', height=3)
plt.show()

# %% [markdown]
# **Observations**
# 1. petal_length and petal_width are the most useful features to identify various flower types.
# 2. While Setosa can be easily identified (linearly seperable), Virginica and Versicolor have some overlap (almost linearly seperable).
# 3. We can find "lines" and "if-else" conditions to build a simple model to classify the flower types.

# %% [markdown]
# # Limitations of Pair Plots

# %%
YouTubeVideo(id='CfhvcF4kVfE', width=900, height=400)
