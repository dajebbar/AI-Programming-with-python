# %%
import numpy as np
import pandas as pd 

from IPython.display import YouTubeVideo, Image

# %% [markdown]
# # How Classification works
# Remember the goal here is to classify Food reviews based on customers' text.

# %%
Image("classification.png")

# %%
YouTubeVideo(id="UpE0CxkjDKw", width=900, height=450)

# %% [markdown]
# # Data Matrix Notation
#
# ## $$D_n = \{ (x_i,y_i)_{i=0}^{n} | x \in R^d, y \in \{0,1\}\}$$
#
# $D_n$: total dataset
# $d$: d dimensions
# $x_i$: text review column vector
# $y_i$: classes 0: negative review, 1: positive review

# %%
YouTubeVideo(id="uiL1Nk_hBBM", width=900, height=450)

# %% [markdown]
# # Classification vs Regression
#
# Fundamentally, classification is about predicting a label and regression is about predicting a quantity.
#   - Classification predictions can be evaluated using accuracy, whereas regression predictions cannot.
#   - Regression predictions can be evaluated using root mean squared error, whereas classification predictions cannot.

# %%
YouTubeVideo(id="FXbF_I3D9q4", width=900, height=450)

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
