# %%
from IPython.display import Image, YouTubeVideo

# %% [markdown]
# # Hypothesis Testing Steps

# %%
Image("hyptest.png")

# %%
YouTubeVideo(id="ceZZt507aFY", width=900, height=400)

# %% [markdown]
# # Statistical Significance

# %%
YouTubeVideo(id="pwBW1aWic_Y", width=900, height=400)

# %% [markdown]
# # Hypothesis Testing - Rejection Regions

# %%
YouTubeVideo(id="RpdgNjNscNQ", width=900, height=400)

# %% [markdown]
# # Hypothesis Testing Assumptions

# %%
YouTubeVideo(id="F1dkr6BggMc", width=900, height=400)

# %% [markdown]
# # What it means when you cannot reject the Null Hypothesis

# %%
YouTubeVideo(id="xdTRtw863xY", width=900, height=400)

# %% [markdown]
# # Student's t-distribution

# %%
YouTubeVideo(id="32CuxWdOlow", width=900, height=400)

# %% [markdown]
# # T-Tests

# %%
YouTubeVideo(id="0Pd3dc1GcHc", width=900, height=400)

# %% [markdown]
# # 1-Tailed And 2-Tailed Tests

# %%
YouTubeVideo(id="XHPIEp-3yC0", width=900, height=400)
