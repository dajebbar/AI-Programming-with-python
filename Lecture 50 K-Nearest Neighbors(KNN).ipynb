# %% [markdown]
# # KNN Geometric Intuition

# %%
import numpy as np
import pandas as pd 

from IPython.display import YouTubeVideo, Image

# %%
YouTubeVideo(id="ca_qJkb8f_k", width=900, height=450)

# %% [markdown]
# # Failure Cases

# %%
YouTubeVideo(id="TLrC1i3UXe0", width=900, height=450)

# %% [markdown]
# # Distance Measures
#
# KNN classification is conventional non-parametric classifier, which has been used as the baseline classifier in many pattern classification problems. It is based on measuring the distances between the test data and each of the training data to decide the final classification output.
# ### Eclidean Distance:
# ### $$dist(A,B) = \sqrt{\frac{\sum_{i=1}^{m}(x_i - y_i)^2}{m}}$$
# ### Minkowsky Distance:
# ### $$ dist\_Minkowsky(A,B) = (\sum_{i=1}^{m}|x_i-y_i|^r)^\frac{1}{r}$$

# %%
YouTubeVideo(id="aOk-_FQGeLs", width=900, height=450)

# %% [markdown]
# # Cosine Distance & Cosine Similarity
# Cosine similarity measures the similarity between two vectors of an inner product space. It is measured by the cosine of the angle between two vectors and determines whether two vectors are pointing in roughly the same direction. It is often used to measure document similarity in text analysis.
# The relation between cosine similarity and cosine distance can be define as below.
#
# ### Similarity decreases when distance between two vectors increases

# %%
Image('sim-dec.png')

# %% [markdown]
# ### Similarity increases when distance between two vectors decreases

# %%
Image('sim-inc.png')

# %% [markdown]
# Cosine similarity says that to find the similarity between two points or vectors we need to **find Angle between them**.
# Formula to find the Cosine Similarity and Distance is as below:
# ### $$1 - cosine\_similarity = cosine\_distance$$
# ### $$cosine\_similarity = \cos\theta = \frac{A.B}{||A||||B||}$$

# %%
YouTubeVideo(id="61MFz12zlgQ", width=900, height=450)

# %%
# %%html
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
# Out:
# <script src="https://cdn.rawgit.com/parente/4c3e6936d0d7a46fd071/raw/65b816fb9bdd3c28b4ddf3af602bfd6015486383/code_toggle.js"></script>
