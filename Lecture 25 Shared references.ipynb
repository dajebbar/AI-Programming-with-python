# %%
from IPython.display import YouTubeVideo
YouTubeVideo('fUGAHZtOM_k', width=900, height=400)

# %%
url = "https://docs.python.org/3/reference/datamodel.html#objects-values-and-types"
